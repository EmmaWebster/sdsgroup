# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn import linear_model
import sklearn.model_selection
from sklearn.model_selection import train_test_split
import sklearn.metrics
import math
import pickle
df =pd.read_pickle('/Users/NikolajJonsson/Downloads/data_description.pkl')
with open('/Users/NikolajJonsson/Downloads/data_description.pkl', 'rb') as f:
    '{0:,}'.format(1000000)
    '1,000,000'

# %%
df
# Out:
#                                      Address Age of car  Automatisk  Blacks  \
# 2           Hjortgårdsvej 23 8600 Silkeborg           6           0     1.0
# 3                Frejasvej 12 4100 Ringsted           5           0     0.0
# 4                 Energivej 12 6670 Holsted           5           0     0.0
# 5                 Lokesvej  4 3400 Hillerød           2           0     0.0
# 7                  Tangmosevej 93 4600 Køge           6           0     0.0
# 8            Ellegårdvej 34 6400 Sønderborg           3           1     1.0
# 9                  Tangmosevej 93 4600 Køge          12           0     1.0
# 10             Hovedgaden 68 4520 Svinninge           6           1     0.0
# 11                 Søllingevej 5 5750 Ringe           3           1     1.0
# 12               Huginsvej 25 4100 Ringsted           0           0     0.0
# 13            Erhvervsparken  6  9500 Hobro           7           0     0.0
# ...

# %%
df.columns
# Out:
# Index(['Address', 'Age of car', 'Automatisk', 'Blacks', 'Car description',
#        'Car model', 'Cold colour', 'Colour', 'Energy label', 'KM driven',
#        'KM per litre', 'Manuel', 'Manufacture year', 'Price new', 'Price used',
#        'Tank size litre', 'Top speed km/h', 'Type of gear', 'Warm colour',
#        'Whites', 'energimaerke energimaerke-a', 'energimaerke energimaerke-a0',
#        'energimaerke energimaerke-a00', 'energimaerke energimaerke-b',
#        'energimaerke energimaerke-c', 'energimaerke energimaerke-d',
#        'energimaerke energimaerke-e', 'energimaerke energimaerke-f',
#        'energimaerke energimaerke-g', 'Total description'],
#       dtype='object')

# %%
nul_fem = df['Age of car'] <5
fem_ti = df['Age of car'] <10
ti_op = df['Age of car'] < 60

# %%
df.plot.scatter(x='Price used', y='KM driven', c='nul_fem') 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/NikolajJonsson/anaconda/lib/python3.6/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     140     try:
# --> 141         rgba = _colors_full_map.cache[c, alpha]
#     142     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# KeyError: ('n', None)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-153-2861f198c5f6> in <module>()
#       1 nul_fem.astype(int)
# ----> 2 df.plot.scatter(x='Price used', y='KM driven', c='nul_fem')
#       3 plt.show()
#
# /Users/NikolajJonsson/anaconda/lib/python3.6/site-packages/pandas/plotting/_core.py in scatter(self, x, y, s, c, **kwds)
#    2796         axes : matplotlib.AxesSubplot or np.array of them
#    2797         """
# ...

# %%
count_gear = (df['Type of gear']).value_counts()
count_gear
count_gear.plot.bar()
plt.show()

# %%
f = sns.barplot(x='Type of gear', y='Price used', data=df)
plt.show()

# %%
sns.boxplot(x='Type of gear', y='Price used', data=df)
plt.show()

# %%
df.plot.scatter('Price new','Price used', alpha = 0.25)
plt.show()

# %%
df.plot.scatter('Age of car','Price used', alpha = 0.25)
plt.show()

# %%
df.plot.scatter('KM driven','Price used', alpha = 0.25)
plt.show()

# %%
df.plot.scatter('KM per litre','Price used', alpha = 0.5)
plt.show()

# %%
df.plot.scatter('Manufacture year','Price used')
plt.show()

# %%
df.plot.bar('Manufacture year','Price used')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
df.plot.scatter(x='Price new', y='Price used', c='KM driven') 
plt.show()

# %%
df.plot.scatter(x='KM driven', y='Price used', c='Age of car') 
plt.show()

# %%
np.mean(df['Price used'])
# Out:
# 212199.70787556379

# %%
np.mean(df['Price new'])
# Out:
# 336819.9716664739

# %%
np.mean(df['KM driven'])
# Out:
# 74931.652596276166

# %%
np.mean(df['Age of car'])
# Out:
# 4.1055857522840293

# %%
pd.describe_option
